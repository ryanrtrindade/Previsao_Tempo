# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanrtrindade/Previsao_Tempo/blob/C%C3%B3digos/graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('/content/drive/MyDrive/python/dataset__chuva_tratado_true.csv')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          4.8
# 1       2008-12-02   Albury      7.4     25.1       0.0          4.8
# 2       2008-12-03   Albury     12.9     25.7       0.0          4.8
# 3       2008-12-04   Albury      9.2     28.0       0.0          4.8
# 4       2008-12-05   Albury     17.5     32.3       1.0          4.8
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          4.8
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          4.8
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          4.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          4.8
# 145459  2017-06-25    Uluru     14.9     22.6       0.0          4.8
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed3pm  \
# ...

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# dtype: object

# %%
sns.countplot(data = df, x = 'RainToday', palette ={'No': 'orange', 'Yes': 'Blue'})
# Out:
# /tmp/ipykernel_13650/1112006610.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x = 'RainToday', palette ={'No': 'orange', 'Yes': 'Blue'})
# <Axes: xlabel='RainToday', ylabel='count'>

# %%
sns.scatterplot(data = df[df['RainToday'] == 'No'], x ='Evaporation', y ='Humidity9am')
# Out:
# <Axes: xlabel='Evaporation', ylabel='Humidity9am'>

# %%
sns.scatterplot(data = df[df['RainToday'] == 'Yes'], x ='Evaporation', y ='Humidity9am')
# Out:
# <Axes: xlabel='Evaporation', ylabel='Humidity9am'>

# %%
sns.scatterplot(data = df[df['RainToday'] == 'No'], x ='Evaporation', y ='Humidity3pm', color = 'Purple')
# Out:
# <Axes: xlabel='Evaporation', ylabel='Humidity3pm'>

# %%
sns.scatterplot(data = df[df['RainToday'] == 'Yes'], x ='Evaporation', y ='Humidity3pm', color = 'Purple')
# Out:
# <Axes: xlabel='Evaporation', ylabel='Humidity3pm'>

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          4.8
# 1       2008-12-02   Albury      7.4     25.1       0.0          4.8
# 2       2008-12-03   Albury     12.9     25.7       0.0          4.8
# 3       2008-12-04   Albury      9.2     28.0       0.0          4.8
# 4       2008-12-05   Albury     17.5     32.3       1.0          4.8
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          4.8
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          4.8
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          4.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          4.8
# 145459  2017-06-25    Uluru     14.9     22.6       0.0          4.8
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed3pm  \
# ...

# %%
sns.lineplot(data = df[df['RainToday'] == 'No'], x = 'Sunshine', y='Evaporation', color = 'Orange')
#
# Out:
# <Axes: xlabel='Sunshine', ylabel='Evaporation'>

# %%
sns.lineplot(data = df[df['RainToday'] == 'Yes'], x = 'Sunshine', y='Evaporation')
# Out:
# <Axes: xlabel='Sunshine', ylabel='Evaporation'>
